# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import nltk
import unicodedata
import re
import env
import acquire
# import prepare
from wordcloud import WordCloud
import nltk.sentiment
pd.set_option('display.max_colwidth', -1)
from time import strftime

import requests
from bs4 import BeautifulSoup
import time
# Out:
# <ipython-input-43-5a5e3725743f>:12: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# acquire.scrape_github_data()

# %%
# df = pd.DataFrame(acquire.scrape_github_data(),columns=['repo','language','readme_contents'])
# df.head()

# %%
# df

# %%
soup = BeautifulSoup(response.text)

# %%
response = requests.get('https://github.com/search?q=bitcoin', headers={'user-agent': 'DS Student'})

# %%
response.text
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-dkuYFW+ra8yYSt342e5pJEeslPSjMcrMvNxlYZMyM/X+/WJHDPvoCuGq3LFojI7B0dQWwZNRiPMnbi9IfUgTaA==" rel="stylesheet" href="https://github.githubassets.com/assets/light-764b98156fab6bcc984addf8d9ee6924.css" /><link crossorigin="anonymous" media="all" integrity="sha512-UrAu23+eyncWvaQFwsLbgSKtmLb2aH1bcT4hJnnRdkaPuY1eu9bumt33FyHHFDX8hskTUNWNkIsMCz7FWQQHwA==" rel="stylesheet" href="https://github.githubassets.com/assets/dark-52b02edb7f9eca7716bda405c2c2db81.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" integrity="sha512-kyu73YWtU8Fu2e7p+Hv094CRhaTvr8yy95vc1SQ2+MeWVWakGeIh/lv9yIFaYAb8J3oM6uBLGcn1kS6M1GxBCQ==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-932bbbdd85ad53c16ed9eee9f87bf4f7.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-jZSKF7Gx8T/AFthO0CUkWWpG5EBlIZb+tIYu8KgP/kizn7fpXEiXJcB73GTZ69wSVVSZ6Y1Cw286qP7pVZr0gg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-8d948a17b1b1f13fc016d84ed0252459.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" integrity="sha512-E02WD8opZPpYu6LM9dlUSIHQgXtLmzi1KxMnaN/SA7k6ILsvpNJjpkBPU1sC98MitAOkCNIe6ozqY8+pHnrHZg==" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-134d960fca2964fa58bba2ccf5d95448.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" integrity="sha512-VWdBPHZj3WCDwaO0N2W8yvDZt7TNZohRIYK4sjjSU56485rCWazxnLr4p3DU8eqn2+eSj3CYYpw4+DzmwHOwew==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-5567413c7663dd6083c1a3b43765bcca.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" integrity="sha512-dw8LrBQMvo9HDd5lo2UEp/tvMVR6zJjrQkQTBVrhyaHDlL1p7UiQ9/xpqYxOz9s7s1Qh5Bjokuzu7NX0U5BeYA==" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-770f0bac140cbe8f470dde65a36504a7.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-VvfOEx8F6LRa1nh/1LEiw5jFLK0kJ+WE1LvuhfNDQkGC8vTGi5yYqCdPEPeBM9lNG7/pQ5cSU2/gOdE03JLCMg==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-56f7ce131f05e8b45ad6787fd4b122c3.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-U0ckQKSRKQsYimFluKQtesny2QRTu0T20/Ti1bM+v4re0n1cY38DmtmJEHEPxgNB+/o/hJSqUBuux5K+4/ke5Q==" rel="stylesheet" href="https://github.githubassets.com/assets/behaviors-53472440a491290b188a6165b8a42d7a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-snW0Fh5VJcWGF5bU9u1W6WMlfbLDsAn9vLx8z6b37RVWr59btn7RpwdWg+w3+gsN31ZwKyYe9MTowM8R8B7WLg==" rel="stylesheet" href="https://github.githubassets.com/assets/tab-size-fix-b275b4161e5525c5861796d4f6ed56e9.css" />\n  \n  \n  \n  <link crossorigin="anonymous" media="all" integrity="sha512-Qzq39I/EbDlTv7Z4hLoKfQAdpFidWgo0oCpa1+8oPObSM4kRqDRBEiVmWumlH1UhX2ixsqym1UEjlkSidOENpw==" rel="stylesheet" href="https://github.githubassets.com/assets/github-433ab7f48fc46c3953bfb67884ba0a7d.css" />\n\n    <script crossorigin="anonymous" defer="defer" integrity="sha512-hCD+yuHX6Po0snD3NcNEqdv4OBBgSdprm+w6CWjfRf/9iXhbuq+6POgT1cqLuNsrBzO5ZIvbOP/X+NTA2HoxJA==" type="application/javascript" src="https://github.githubassets.com/assets/environment-8420feca.j ...

# %%
repos = soup.find_all('div', class_ = 'f4 text-normal')
repos
# Out:
# [<div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":1,"click_id":1181927,"result":{"id":1181927,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxMTgxOTI3","model_name":"Repository","url":"https://github.com/bitcoin/bitcoin"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="2f9bb81948d1cfd1e2c586d2eda7f6f8900f679e47c524ada9abda2363ed2573" href="/bitcoin/bitcoin">bitcoin/<em>bitcoin</em></a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":2,"click_id":12044132,"result":{"id":12044132,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxMjA0NDEzMg==","model_name":"Repository","url":"https://github.com/bitcoinbook/bitcoinbook"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="f1243b513141106eb5cf93b5799f278a99aca5341d616f29ddbffa25f23f86ac" href="/bitcoinbook/bitcoinbook">bitcoinbook/<em>bitcoinbook</em></a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":3,"click_id":14514251,"result":{"id":14514251,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxNDUxNDI1MQ==","model_name":"Repository","url":"https://github.com/bitcoinj/bitcoinj"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="4b929aa17280b9295d81a42893a9834fee3f2412cba0cb7fb4f8aa2472ba64a4" href="/bitcoinj/bitcoinj">bitcoinj/<em>bitcoinj</em></a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":4,"click_id":14531737,"result":{"id":14531737,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxNDUzMTczNw==","model_name":"Repository","url":"https://github.com/bitcoin/bips"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="12d00171c55ea8ef3b7f3f562cd387004b5cc7c62e090b75eebe281339a92853" href="/bitcoin/bips">bitcoin/bips</a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":5,"click_id":1701968,"result":{"id":1701968,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxNzAxOTY4","model_name":"Repository","url":"https://github.com/bitcoinjs/bitcoinjs-lib"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="5673c33eb2ec9a423875491c2927242c1bb3a321255dfa1d7d2e3282e67040fb" href="/bitcoinjs/bitcoinjs-lib">bitcoinjs/<em>bitcoinjs</em>-lib</a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":6,"click_id":5274894,"result":{"id":5274894,"global_relay_id":"MDEwOlJlcG9zaXRvcnk1Mjc0ODk0","model_name":"Repository","url":"https://github.com/spesmilo/electrum"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="b7e84214a5d8768c468bbf6a43d68bec024f9531942a9a099cce6642e2567e77" href="/spesmilo/electrum">spesmilo/electrum</a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":7,"click_id":3886965,"result":{"id":3886965,"global_relay_id":"MDEwOlJlcG9zaXRvcnkzODg2OTY1","model_name":"Repository","url":"https://github.com/bitcoin-wallet/bitcoin-wallet"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="c90142f96ad05448379d6c8b32b9ddc0448d3e2a545af511bdc8af617f29c057" href="/bitcoin-wallet/bitcoin-wallet">bitcoin-wallet/<em>bitcoin</em>-wallet</a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":8,"click_id":2809086,"result":{"id":2809086,"global_relay_id":"MDEwOlJlcG9zaXRvcnkyODA5MDg2","model_name":"Repository","url":"https://github.com/etotheipi/BitcoinArmory"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="79fbf41bc70a3444d3958ad9f4b596e7d198b363a83cdf485cd291bb9c7252b5" href="/etotheipi/BitcoinArmory">etotheipi/<em>Bitcoin</em>Armory</a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":9,"click_id":2304420,"result":{"id":2304420,"global_relay_id":"MDEwOlJlcG9zaXRvcnkyMzA0NDIw","model_name":"Repository","url":"https://github.com/bitcoin-dot-org/Bitcoin.org"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="c905c117106da55f51e9641fcecc10ff61874397b38450f73ab9f0493d21bd3f" href="/bitcoin-dot-org/Bitcoin.org">bitcoin-dot-org/<em>Bitcoin</em>.org</a>
#  </div>,
#  <div class="f4 text-normal">
#  <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":10,"click_id":1108078,"result":{"id":1108078,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxMTA4MDc4","model_name":"Repository","url":"https://github.com/jgarzik/cpuminer"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="b45e002dd3ae971affe5994b8ab2d653ccca49fb15fcc2533c3418f1803f1511" href="/jgarzik/cpuminer">jgarzik/cpuminer</a>
#  </div>]

# %%
repo = repos[0]
repo
# Out:
# <div class="f4 text-normal">
# <a class="v-align-middle" data-hydro-click='{"event_type":"search_result.click","payload":{"page_number":1,"per_page":10,"query":"bitcoin","result_position":1,"click_id":1181927,"result":{"id":1181927,"global_relay_id":"MDEwOlJlcG9zaXRvcnkxMTgxOTI3","model_name":"Repository","url":"https://github.com/bitcoin/bitcoin"},"originating_url":"https://github.com/search?q=bitcoin","user_id":null}}' data-hydro-click-hmac="2f9bb81948d1cfd1e2c586d2eda7f6f8900f679e47c524ada9abda2363ed2573" href="/bitcoin/bitcoin">bitcoin/<em>bitcoin</em></a>
# </div>

# %%
extension = repo.a.attrs['href']
extension
# Out:
# '/bitcoin/bitcoin'

# %%
def get_extensions():
    extension_list = []
    response = requests.get('https://github.com/search?q=bitcoin', headers={'user-agent': 'DS Student'})
    soup = BeautifulSoup(response.text)
    repos = soup.find_all('div', class_ = 'f4 text-normal')
    for repo in repos:
        time.sleep(2)
        extension = repo.a.attrs['href']
        extension_list.append(extension)
    return extension_list

# %%
def get_extension(repo):
    extension = repo.a.attrs['href']
    return extension

# %%
get_extension(repo)
# Out:
# '/bitcoin/bitcoin'

# %%
temp_list = get_extensions()
temp_list
# Out:
# ['/bitcoin/bitcoin',
#  '/bitcoinbook/bitcoinbook',
#  '/bitcoinj/bitcoinj',
#  '/bitcoin/bips',
#  '/bitcoinjs/bitcoinjs-lib',
#  '/spesmilo/electrum',
#  '/etotheipi/BitcoinArmory',
#  '/bitcoin-wallet/bitcoin-wallet',
#  '/bitcoin-dot-org/Bitcoin.org',
#  '/jgarzik/cpuminer']

# %% [markdown]
# <em class="current" data-total-pages="100">1</em>
